# %% [markdown]
# Neural network come in to play in the case of non-linear models like this:
#
# ![Screen%20Shot%202018-07-19%20at%207.22.51%20PM.png](attachment:Screen%20Shot%202018-07-19%20at%207.22.51%20PM.png)
#
# - Combining 2 models by a sigmoid function
#
# ![Screen%20Shot%202018-07-19%20at%207.26.07%20PM.png](attachment:Screen%20Shot%202018-07-19%20at%207.26.07%20PM.png)
#
# - Combining 2 models by weighing one more than the other and using a sigmoid funciton
#
# ![Screen%20Shot%202018-07-19%20at%207.27.32%20PM.png](attachment:Screen%20Shot%202018-07-19%20at%207.27.32%20PM.png)
#
#
# Thus, perceptrons are the building blocks of Neural networks

# %% [markdown]
# ## Feed Forward
# Feedforward is the process neural networks use to turn the input into an output.
#
# - In a simple perceptron
#
# ![Screen%20Shot%202018-07-19%20at%207.43.27%20PM.png](attachment:Screen%20Shot%202018-07-19%20at%207.43.27%20PM.png)
#
# ![Screen%20Shot%202018-07-19%20at%207.44.30%20PM.png](attachment:Screen%20Shot%202018-07-19%20at%207.44.30%20PM.png)
#
# - In a multilayer perceptron
#
# ![Screen%20Shot%202018-07-19%20at%207.45.00%20PM.png](attachment:Screen%20Shot%202018-07-19%20at%207.45.00%20PM.png)

# %% [markdown]
# ## Error Function
# ![Screen%20Shot%202018-07-19%20at%207.48.58%20PM.png](attachment:Screen%20Shot%202018-07-19%20at%207.48.58%20PM.png)

# %% [markdown]
# ## Backpropagation
# 1. Doing a feedforward operation.
# 2. Comparing the output of the model with the desired output.
# 3. Calculating the error.
# 4. Running the feedforward operation backwards (backpropagation) to spread the error to each of the weights.
# 5. Use this to update the weights, and get a better model.
# 6. Continue this until we have a model that is good.
