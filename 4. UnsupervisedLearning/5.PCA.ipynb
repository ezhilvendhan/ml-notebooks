# %% [markdown]
# # Principal Component Analysis (PCA)
# PCA shifts the axes center to the datapoints' center as below and lets us know how the important it is.
#
# ![Screen%20Shot%202018-07-10%20at%204.27.56%20PM.png](attachment:Screen%20Shot%202018-07-10%20at%204.27.56%20PM.png)
#
# - Principal axis of new co-ordinate $\Delta {x} $ and $ \Delta {y}$ i.e. the slope.
# The amount of variation in x for the corresponding y in the new x-axis and vice versa
#
# ![Screen%20Shot%202018-07-10%20at%204.33.57%20PM.png](attachment:Screen%20Shot%202018-07-10%20at%204.33.57%20PM.png)
#
# ![Screen%20Shot%202018-07-10%20at%205.37.36%20PM.png](attachment:Screen%20Shot%202018-07-10%20at%205.37.36%20PM.png)

# %% [markdown]
# Which data is ready for PCA?
#
# ![Screen%20Shot%202018-07-10%20at%205.45.19%20PM.png](attachment:Screen%20Shot%202018-07-10%20at%205.45.19%20PM.png)
