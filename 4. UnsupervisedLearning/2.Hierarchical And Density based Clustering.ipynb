# %% [markdown]
# ### Drawback of K-means
# * Not so good at some patterns which do not follow the distance to center definition of K-means as below
# ![Screen%20Shot%202018-07-03%20at%209.53.09%20AM.png](attachment:Screen%20Shot%202018-07-03%20at%209.53.09%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202018-07-03%20at%209.55.35%20AM.png](attachment:Screen%20Shot%202018-07-03%20at%209.55.35%20AM.png)
